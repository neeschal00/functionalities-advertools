# %%
import pandas as pd
# from ydata_profiling import ProfileReport
import os
from collections import Counter
import re

# %%
import advertools as adv

# %%
adv.robotstxt_to_df("https://www.pythonspeed.com/robots.txt")
# Out:
# 2023-08-06 11:25:17,127 | INFO | robotstxt.py:381 | robotstxt_to_df | Getting: https://www.pythonspeed.com/robots.txt
#     directive                              content  \
# 0  User-agent                                    *
# 1       Allow                                    /
# 2    Disallow                            /atom.xml
# 3     Sitemap  https://pythonspeed.com/sitemap.xml
#
#                                      etag                       robotstxt_url  \
# 0  "960b5beb46fbba859b494d4e0d886956-ssl"  https://pythonspeed.com/robots.txt
# 1  "960b5beb46fbba859b494d4e0d886956-ssl"  https://pythonspeed.com/robots.txt
# 2  "960b5beb46fbba859b494d4e0d886956-ssl"  https://pythonspeed.com/robots.txt
# 3  "960b5beb46fbba859b494d4e0d886956-ssl"  https://pythonspeed.com/robots.txt
#
#                      download_date
# 0 2023-08-06 15:25:17.598495+00:00
# 1 2023-08-06 15:25:17.598495+00:00
# 2 2023-08-06 15:25:17.598495+00:00
# 3 2023-08-06 15:25:17.598495+00:00

# %%
robots_test = adv.robotstxt_test('https://facebook.com/robots.txt',
               user_agents=['Googlebot'],
               urls=['https://facebook.com/', '/ajax/', 'https://facebook.com/articles/numpy-is-slow/', 'https://facebook.com/articles/speeding-up-numba/','https://facebook.com/datascience/'])

# %%
robots_test
# Out:
#                      robotstxt_url user_agent  \
# 0  https://facebook.com/robots.txt  Googlebot
# 1  https://facebook.com/robots.txt  Googlebot
# 2  https://facebook.com/robots.txt  Googlebot
# 3  https://facebook.com/robots.txt  Googlebot
# 4  https://facebook.com/robots.txt  Googlebot
#
#                                            url_path  can_fetch
# 0                                            /ajax/      False
# 1                             https://facebook.com/       True
# 2      https://facebook.com/articles/numpy-is-slow/       True
# 3  https://facebook.com/articles/speeding-up-numba/       True
# 4                 https://facebook.com/datascience/       True

# %%
stopwords = adv.stopwords

# %%
stopwords.keys()
print(list(stopwords["english"]))
# Out:
# ['but', 'himself', 'eight', 'used', 'may', 'seeming', 'empty', 'third', 'because', 'him', 'noone', 'rather', 'ever', 'meanwhile', 'two', 'put', 'did', 'hereupon', 'such', 'neither', 'beforehand', 'while', 'do', 'side', 'thereafter', 'everything', 'then', 'fifty', 'herein', 'thus', 'show', 'about', 'besides', 'themselves', 'to', 'less', 'out', 'yours', 'anything', 'where', 'until', 'however', 'can', 'the', 'your', 'some', 'per', 'except', 'several', 'yourself', 'of', 'no', 'formerly', 'always', 'due', 'will', 'thereby', 'part', 'ca', 'full', 'here', 'me', 'else', 'perhaps', 'in', 'after', 'with', 'am', 'please', 'been', 'though', 'twenty', 'doing', 'moreover', 'must', 'when', 'somehow', 'anywhere', 'latter', 'last', 'down', 'than', 'whose', 'would', 'ours', 'wherein', 'afterwards', 'never', 'often', 'that', 'seem', 'whereas', 'same', 'how', 'off', 'anyway', 'together', 'if', 'still', 'more', 'before', 'be', 'onto', 'these', 'now', 'itself', 'not', 'ourselves', 'nothing', 'someone', 'b
# ...

# %%
def keywords(url):
    adv.crawl(
                url_list=[url],
                output_file="output/crawl_output.jl",
                custom_settings={"LOG_FILE": "logs/crawlLogs/keywords.log"},
                )
    crawlDf = pd.read_json("output/crawl_output.jl",lines=True)
    body_text = crawlDf["body_text"][0].lower()
    pattern = r"[^a-zA-Z0-9@\s]"
    body_text = re.sub(pattern,"",body_text)
    for text in stopwords["english"]:
        body_text = body_text.replace(" "+text.lower()+" ","")
    print(type(body_text))
    keywords = body_text.split()
    keywords = dict(Counter(keywords))
    keywords = sorted(keywords.items(),key=lambda x: x[1],reverse=True)
    print(keywords)
    print(dict(keywords))
    return dict(keywords)

keywords("https://pythonspeed.com/articles/celery-performance/")
# Out:
# <class 'str'>
# ...

# %%
def titleAnalysis(title = None):
    if title:
        lengthT = len(title)
        if lengthT > 50 and lengthT < 70:
            return {
                "status": "success",
                "title": title,
                "length": lengthT,
                "appropriate": True,
                "description": f"The title is set and the length being {lengthT} is appropriate for title length which must be approx. 50-70 chars long."
            }
        else:
            return {
                "status": "success",
                "title": title,
                "length": lengthT,
                "appropriate": False,
                "description": f"The title is set and the length being {lengthT} is not appropriate for title length which must be approx. 50-70 chars long."
            }
    else:
        return {
                "status": "failed",
                "title": title,
                "length": None,
                "appropriate": False,
                "description": f"The title is not set and title length which must be approx. 50-70 chars long."
            }

print(titleAnalysis("Finding performance bottlenecks in Celery tasks in python"))
# Out:
# {'status': 'success', 'title': 'Finding performance bottlenecks in Celery tasks in python', 'length': 57, 'appropriate': True, 'description': 'The title is set and the length being 57 is appropriate for title length which must be approx. 50-70 chars long.'}

# %%
crawlDf = pd.read_json("output/crawl_output.jl",lines=True)
crawlDf.columns
# Out:
# Index(['url', 'title', 'meta_desc', 'viewport', 'h1', 'h2', 'h3', 'h4',
#        'canonical', 'alt_href', 'og:title', 'og:locale', 'og:description',
#        'og:url', 'og:site_name', 'og:image', 'og:type', 'twitter:card',
#        'twitter:site', 'twitter:creator', 'jsonld_@type', 'jsonld_image',
#        'jsonld_description', 'jsonld_url', 'jsonld_headline',
#        'jsonld_dateModified', 'jsonld_datePublished', 'jsonld_@context',
#        'jsonld_mainEntityOfPage.@type', 'jsonld_mainEntityOfPage.@id',
#        'jsonld_author.@type', 'jsonld_author.name', 'body_text', 'size',
#        'download_timeout', 'download_slot', 'download_latency', 'depth',
#        'status', 'links_url', 'links_text', 'links_nofollow', 'nav_links_url',
#        'nav_links_text', 'nav_links_nofollow', 'header_links_url',
#        'header_links_text', 'header_links_nofollow', 'footer_links_url',
#        'footer_links_text', 'footer_links_nofollow', 'img_src', 'img_width',
# ...

# %%
def metaDescripton(description):
    if description:
        lengthT = len(description)
        if lengthT > 150 and lengthT < 170:
            return {
                "status": "success",
                "description": description,
                "length": lengthT,
                "appropriate": True,
                "description": f"The description is set and the length being {lengthT} is appropriate for description length which must be approx. 50-70 chars long."
            }
        else:
            return {
                "status": "success",
                "description": description,
                "length": lengthT,
                "appropriate": False,
                "description": f"The description is set and the length being {lengthT} is not appropriate for description length which must be approx. 50-70 chars long."
            }
    else:
        return {
                "status": "failed",
                "description": description,
                "length": None,
                "appropriate": False,
                "description": f"The description is not set and description length which must be approx. 50-70 chars long."
            }

# %%
def headingTitles():
    hTitles = ["h1","h2","h3","h4","h6"]
    setTitles = [title for title in hTitles if title in df.columns]

# %%
logsDf = adv.crawllogs_to_df("logs/crawlLogs/keywords.log")
logsDf
# Out:
#                  time           middleware  level  message domain method  \
# 0 2023-07-05 11:04:00   scrapy.core.engine  DEBUG  Crawled    NaN    GET
# 1 2023-07-05 11:04:00   scrapy.core.engine  DEBUG  Crawled    NaN    GET
# 2 2023-07-05 11:04:01  scrapy.core.scraper  DEBUG  Scraped    NaN    NaN
#
#                                      url status referer method_to redirect_to  \
# 0  https://gerwholesalers.com/robots.txt    200    None       NaN         NaN
# 1            https://gerwholesalers.com/    200    None       NaN         NaN
# 2            https://gerwholesalers.com/    200     NaN       NaN         NaN
#
#   method_from redirect_from blocked_urls
# 0         NaN           NaN          NaN
# 1         NaN           NaN          NaN
# 2         NaN           NaN          NaN

# %%
def analyzeCrawlLogs():
    logsDf = adv.crawllogs_to_df(logs_file_path="output_file.log")

    logs_m = logsDf["message"].value_counts().to_json()
    logs_s = logsDf["status"].value_counts().to_json()
    logs_mi = logsDf["middleware"].value_counts().to_json()

    logsDf = logsDf.reset_index(drop=True).to_html(
        classes="table", justify="center"
    )

    logsDf = logsDf.replace(
        'class="dataframe table"',
        'class="table table-primary table-striped text-center"',
    )
    
    
    return {
        'logs_message': logs_m,
        'logs_status': logs_s,
        'logs_mi': logs_mi,
        'logs_dt': logsDf 
    }

# %%
import validators

# %%
log_an = adv.crawllogs_to_df("output_file.log")
# profile = ProfileReport(log_an,minimal=False,title="testing")

# profile.to_file("report.html")

log_m = log_an["message"].value_counts()
log_m = log_m.to_json()
log_m
# Out:
# '{"Filtered":136,"Crawled":112,"Scraped":111,"Forbidden":1,"Redirect":1}'

# %%
serp_imgs = adv.serp_goog(q=["football","basketball"],cx="c4fc391654b014f8a", 
                          key="AIzaSyDAfhTl8ipspvo1c5qbuVf4HT2PBuxymRg",
                          exactTerms=["messi"],excludeTerms=["GOAT"]
                          )
# Out:
# 2023-06-15 10:50:20,169 | INFO | serp.py:728 | serp_goog | Requesting: q=football, cx=c4fc391654b014f8a, key=AIzaSyDAfhTl8ipspvo1c5qbuVf4HT2PBuxymRg, exactTerms=messi, excludeTerms=GOAT
# 2023-06-15 10:50:20,688 | INFO | serp.py:728 | serp_goog | Requesting: q=basketball, cx=c4fc391654b014f8a, key=AIzaSyDAfhTl8ipspvo1c5qbuVf4HT2PBuxymRg, exactTerms=messi, excludeTerms=GOAT

# %%
serp_imgs
# Out:
#    excludeTerms exactTerms searchTerms  rank  \
# 0          GOAT      messi    football     1
# 1          GOAT      messi    football     2
# 2          GOAT      messi    football     3
# 3          GOAT      messi    football     4
# 4          GOAT      messi    football     5
# 5          GOAT      messi    football     6
# 6          GOAT      messi    football     7
# 7          GOAT      messi    football     8
# 8          GOAT      messi    football     9
# 9          GOAT      messi    football    10
# 10         GOAT      messi  basketball     1
# 11         GOAT      messi  basketball     2
# 12         GOAT      messi  basketball     3
# 13         GOAT      messi  basketball     4
# 14         GOAT      messi  basketball     5
# 15         GOAT      messi  basketball     6
# 16         GOAT      messi  basketball     7
# 17         GOAT      messi  basketball     8
# 18         GOAT      messi  basketball     9
# 19         GOAT      messi  basketball    10
#
# ...
